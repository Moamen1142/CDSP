# %% [markdown]
# ### 1-Import Important Packages

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ### 2-Read Data

# %%
netflix=pd.read_csv('Data/netflix_titles.csv')
amazon=pd.read_csv('Data/amazon_prime_titles.csv')
hulu=pd.read_csv('Data/hulu_titles.csv')
dinsey=pd.read_csv('Data/disney_plus_titles.csv')

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7585 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
hulu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 288.2+ KB

# %%
dinsey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 136.1+ KB

# %% [markdown]
# ### 3.1.1-Netflix Data Understanding

# %%
netflix_numeric=netflix[['show_id','duration']]
netflix_categorical=netflix[['type','title','director','cast','country','rating','listed_in','description']]
netflix_datetime=netflix[['date_added','release_year']]

# %%
netflix.isna().mean()*100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %% [markdown]
# ### 3.1.2-Netflix Data Cleaning

# %%
# netlix dataframe that will be used for analysis
netflix_df=netflix[['type','title','director','cast','country','date_added','release_year','rating','duration','listed_in']]
netflix_df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# for the director column it is preferable to keep it and replace NaN with N/A
netflix_df.director=np.where(netflix_df.director.isna(),'N/A',netflix_df.director)
netflix_df.director.isna().sum()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_24484\1446079596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_df.director=np.where(netflix_df.director.isna(),'N/A',netflix_df.director)
# np.int64(0)

# %%
# for the cast column we don't need all tehse actors we only need the lead and supporting actors
netflix_df[['lead_actor','supporting_actor']]=netflix_df.cast.str.split(', ',regex=True,expand=True).iloc[:,:2]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_24484\2768989116.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_df[['lead_actor','supporting_actor']]=netflix_df.cast.str.split(', ',regex=True,expand=True).iloc[:,:2]

# %%
# replace actors that are not available with N/A
netflix_df.lead_actor=np.where(netflix_df.lead_actor.isna(),'N/A',netflix_df.lead_actor)
netflix_df.supporting_actor=np.where(netflix_df.supporting_actor.isna(),'N/A',netflix_df.supporting_actor)
netflix_df.drop(columns=['cast'],inplace=True)

# %%
netflix_df.head()
# Out:
#       type                  title         director        country  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1  TV Show          Blood & Water              N/A   South Africa
# 2  TV Show              Ganglands  Julien Leclercq            NaN
# 3  TV Show  Jailbirds New Orleans              N/A            NaN
# 4  TV Show           Kota Factory              N/A          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in     lead_actor  \
# 0                                      Documentaries            N/A
# 1    International TV Shows, TV Dramas, TV Mysteries     Ama Qamata
# ...

# %%
# date_added and release_year should be in datetime format
netflix_df.date_added=pd.to_datetime(netflix_df.date_added.str.strip(),format="%B %d, %Y")
netflix_df.release_year=pd.to_numeric(netflix_df.release_year)

# %%
# Drop rows where date_added is not available
netflix_df=netflix_df[netflix_df.date_added.notna()]

# %%
# ratings of value_counts
netflix_df.rating.value_counts(dropna=False)
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NaN            4
# NC-17          3
# UR             3
# 66 min         1
# 74 min         1
# 84 min         1
# Name: count, dtype: int64

# %%
netflix_df=netflix_df[netflix_df.rating.str.find('min')==-1]

# %%
# duration should be an integer
netflix_df.duration=netflix_df.duration.apply(lambda x:''.join(i for i in str(x) if i.isnumeric()))

# %%
netflix_df.duration=pd.to_numeric(netflix_df.duration)

# %%
# use mode value for missing values in country
netflix_df.country=netflix_df.country.fillna(netflix_df.country.mode()[0])

# %%
netflix_df.reset_index(inplace=True)

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             8790 non-null   int64
#  1   type              8790 non-null   object
#  2   title             8790 non-null   object
#  3   director          8790 non-null   object
#  4   country           8790 non-null   object
#  5   date_added        8790 non-null   datetime64[ns]
#  6   release_year      8790 non-null   int64
#  7   rating            8790 non-null   object
#  8   duration          8790 non-null   int64
#  9   listed_in         8790 non-null   object
#  10  lead_actor        8790 non-null   object
#  11  supporting_actor  8790 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 824.2+ KB

# %%
# netflix movies duration
netflix_df[netflix_df.type=='Movie']['duration'].describe()
# Out:
# count    6126.000000
# mean       99.584884
# std        28.283225
# min         3.000000
# 25%        87.000000
# 50%        98.000000
# 75%       114.000000
# max       312.000000
# Name: duration, dtype: float64

# %%
# netflix TV Shows duration
netflix_df[(netflix_df.type=='TV Show')&(netflix_df.duration>4)]
# Out:
#       index     type                          title         director  \
# 8         8  TV Show  The Great British Baking Show  Andy Devonshire
# 21       21  TV Show         Resurrection: Ertugrul              N/A
# 55       55  TV Show                      Nailed It              N/A
# 65       65  TV Show                   Numberblocks              N/A
# 67       67  TV Show              Saved by the Bell              N/A
# ...     ...      ...                            ...              ...
# 8405   8422  TV Show             The Mind of a Chef              N/A
# 8425   8442  TV Show              The Office (U.S.)              N/A
# 8540   8557  TV Show                  The West Wing              N/A
# 8693   8710  TV Show                          Weeds              N/A
# 8709   8726  TV Show           When Calls the Heart              N/A
#
#              country date_added  release_year rating  duration  \
# 8     United Kingdom 2021-09-24          2021  TV-14         9
# ...

# %%
netflix_df.drop_duplicates(inplace=True)

# %% [markdown]
# ### 3.1.3-Netflix EDA

# %%
# Ratio of Movies to TV Shows
px.pie(netflix_df.groupby(by='type')['title'].count(),
       names=netflix_df.groupby(by='type')['title'].count().index,
       values=netflix_df.groupby(by='type')['title'].count().values,
       color_discrete_sequence=['#221f1f', '#b20710'],)

# %%
# listed_in columns has masny categories so we will use get dummies
px.bar_polar(r=netflix_df[netflix_df.type=='Movie']['listed_in'].str.get_dummies(sep=', ').sum().drop(index="Movies").values,
             theta=netflix_df[netflix_df.type=='Movie']['listed_in'].str.get_dummies(sep=', ').sum().drop(index="Movies").index,
             color_discrete_sequence=['#221f1f'])

# %%
# listed_in columns has masny categories so we will use get dummies
px.bar_polar(r=netflix_df[netflix_df.type=='TV Show']['listed_in'].str.get_dummies(sep=', ').sum().drop(index="TV Shows").values,
             theta=netflix_df[netflix_df.type=='TV Show']['listed_in'].str.get_dummies(sep=', ').sum().drop(index="TV Shows").index,
             color_discrete_sequence=['#b20710', '#e50914','#f5f5f1'],)

# %%
# Movies release through time
px.bar(data_frame=netflix_df[netflix_df.type=='Movie'].groupby(by='release_year')['title'].count(),
       x=netflix_df[netflix_df.type=='Movie'].groupby(by='release_year')['title'].count().index,
       y=netflix_df[netflix_df.type=='Movie'].groupby(by='release_year')['title'].count().values,
       color_discrete_sequence=['#221f1f'])

# %%
# TV Shows release through time
px.bar(data_frame=netflix_df[netflix_df.type=='TV Show'].groupby(by='release_year')['title'].count(),
       x=netflix_df[netflix_df.type=='TV Show'].groupby(by='release_year')['title'].count().index,
       y=netflix_df[netflix_df.type=='TV Show'].groupby(by='release_year')['title'].count().values,
       color_discrete_sequence=['#221f1f'])

# %% [markdown]
# Most of movies and TV shows were released during the pandemic

# %%
px.bar(data_frame=netflix_df.country.str.rstrip(',').str.get_dummies(sep=', ').sum().sort_values(ascending=False)[:10],
       x=netflix_df.country.str.rstrip(',').str.get_dummies(sep=', ').sum().sort_values(ascending=False)[:10].index,
       y=netflix_df.country.str.rstrip(',').str.get_dummies(sep=', ').sum().sort_values(ascending=False)[:10].values,
       title='Top 10 Countries on Netflix',
       color_discrete_sequence=['#e50914'])

# %%
# Movies and TV Shows split by country
x_total=netflix_df.country.str.rstrip(',').str.get_dummies(sep=', ').sum().sort_values(ascending=False).to_frame().reset_index()
x_total.columns=['Country', 'Total']
x_total.head()
x_movies=netflix_df[netflix_df.type=='Movie']['country'].str.rstrip(',').str.get_dummies(sep=', ').sum().sort_values(ascending=False).to_frame().reset_index()
x_movies.columns=['Country', 'Movies']
x_movies.head()
x_shows=netflix_df[netflix_df.type=='TV Show']['country'].str.rstrip(',').str.get_dummies(sep=', ').sum().sort_values(ascending=False).to_frame().reset_index()
x_shows.columns=['Country', 'Shows']
x_shows.head()
x_total=x_total.merge(x_movies,how='inner',on=['Country'])
x_total=x_total.merge(x_shows,how='inner',on=['Country'])
x_total.head()
# Out:
#           Country  Total  Movies  Shows
# 0   United States   4510    3188   1322
# 1           India   1046     962     84
# 2  United Kingdom    805     534    271
# 3          Canada    445     319    126
# 4          France    393     303     90

# %%
px.bar(data_frame=x_total[:11],
       y='Country',
       x=['Movies','Shows'],
       barmode='stack',
       color_discrete_sequence=['#221f1f', '#b20710', '#e50914','#f5f5f1'])

# %% [markdown]
# Almost all top countries watch movies more than TV shows except for South Korea and Japan which have more TV Shows than movies

# %%
# Rating Distribution for each type
y=data_frame=netflix_df.groupby(by=['type','rating'])['title'].count().to_frame().reset_index()
y.head()
px.sunburst(data_frame=y,
            path=['type','rating'],
            values='title',
            title='Netflix Ratings',
            color_discrete_sequence=['#221f1f', '#b20710', '#e50914','#f5f5f1'])

# %%
mask = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}
z=netflix_df.groupby(by=['type',netflix_df.rating.map(mask)])['title'].count().to_frame().reset_index()
px.sunburst(data_frame=z,
            path=['type','rating'],
            values='title',
            title='Netflix Ratings',
            color_discrete_sequence=['#221f1f', '#b20710', '#e50914','#f5f5f1'])

# %%
px.pie(data_frame=netflix_df[netflix_df.country.str.contains('United States')].groupby(by=netflix_df.rating.map(mask))['title'].count().to_frame().reset_index(),
       names='rating',
       values='title',
       title='USA Netflix ratings distribution',
       color_discrete_sequence=['#221f1f', '#b20710', '#e50914','#f5f5f1'])

# %%
px.pie(data_frame=netflix_df[netflix_df.country.str.contains('Egypt')].groupby(by=netflix_df.rating.map(mask))['title'].count().to_frame().reset_index(),
       names='rating',
       values='title',
       title='Egypt Netflix ratings distribution',
       color_discrete_sequence=['#221f1f', '#b20710', '#e50914','#f5f5f1'])

# %%
# When does Netflix releases most of its content during the year
px.area(data_frame=netflix_df.groupby(by=netflix_df['date_added'].dt.month_name())['title'].count().sort_values(ascending=False),
        x=netflix_df.groupby(by=netflix_df['date_added'].dt.month_name())['title'].count().sort_values(ascending=False).index,
        y=netflix_df.groupby(by=netflix_df['date_added'].dt.month_name())['title'].count().sort_values(ascending=False).values,
        title='Netflix releases distributed across the year',
        color_discrete_sequence=['#b20710'])

# %%
netflix_df.to_csv('netflix_cleaned.csv',index=False)

# %%
netflix_df[(netflix_df.country.str.contains('Egypt'))&(netflix_df.type=='Movie')].groupby('lead_actor').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 netflix_df[(netflix_df.country.str.contains('Egypt'))&(netflix_df.type=='Movie')].groupby('lead_actor').count()
#
# NameError: name 'netflix_df' is not defined

# %% [markdown]
# ### 3.1.4-Netflix Deployment

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns

df = pd.read_csv('netflix_cleaned.csv')
df['date_added'] = pd.to_datetime(df['date_added'])
df['duration'] = pd.to_numeric(df['duration'])

st.set_page_config(page_title='Netflix Dashboard', layout='wide')

selected_type = st.sidebar.selectbox('Type', options=['Movie', 'TV Show'])

# min_year = int(df[df.type==selected_type]['release_year'].min())
# max_year = int(df[df.type==selected_type]['release_year'].max())
# year_range = st.sidebar.slider('Year range', min_year, max_year, (min_year, max_year))

all_countries=df.country.str.rstrip(',').str.get_dummies(sep=', ').columns
selected_country=st.sidebar.selectbox('country',options=all_countries)

# if selected_type=='Movie':
#     all_genres=df[df.type==selected_type]['listed_in'].str.get_dummies(sep=', ').drop(columns=['Movies']).columns
# else:
#     all_genres=df[df.type==selected_type]['listed_in'].str.get_dummies(sep=', ').drop(columns=['TV Shows']).columns
# selected_genre=st.sidebar.selectbox('genre',options=all_genres)

filtered_df=df[(df.type==selected_type)&(df.country.str.contains(selected_country))]

tab1,tab2=st.tabs(['overview','plots'])
with tab1:
    st.dataframe(filtered_df[['title','director','rating','lead_actor','supporting_actor']])
    col1,col2,col3=st.columns(3)
    col1.metric('number of titles',len(filtered_df))
    col2.metric('number of directors',filtered_df[filtered_df.director!='N/A']['director'].nunique())
    col3.metric('average duration',round(number=filtered_df['duration'].mean(),ndigits=0))
with tab2:
    col1, col2 = st.columns(2)

    top_genres=filtered_df['listed_in'].str.rstrip(',').str.get_dummies(sep=', ').sum().to_frame(name='Titles').reset_index().head()
    top_genres.columns=['Genre','Titles']
    fig1=px.pie(data_frame=top_genres,names='Genre',values='Titles',color_discrete_sequence=['#221f1f', '#b20710', '#e50914','#f5f5f1'])
    
    top_lead=filtered_df.groupby('lead_actor')['title'].count().sort_values(ascending=False).head(5).reset_index()
    top_lead.columns = ['Actor', 'Appearances']
    fig2=px.bar(top_lead,x='Appearances',y='Actor',title='Top 5 Lead Actors',orientation='h',color_discrete_sequence=['#221f1f', '#b20710', '#e50914','#f5f5f1'])

    mask = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
    }
    top_ratings=filtered_df.groupby(filtered_df.rating.map(mask))['title'].count().reset_index()
    top_ratings.columns=['Rating','Titles']
    fig3=px.pie(data_frame=top_ratings,names='Rating',values='Titles',color_discrete_sequence=['#221f1f', '#b20710', '#e50914','#f5f5f1'])

    top_supprt=filtered_df.groupby('supporting_actor')['title'].count().sort_values(ascending=False).head(5).reset_index()
    top_supprt.columns = ['Actor', 'Appearances']
    fig4=px.bar(top_supprt,x='Appearances',y='Actor',title='Top 5 Supporting Actors',orientation='h',color_discrete_sequence=['#221f1f', '#b20710', '#e50914','#f5f5f1'])

    with col1:
        st.plotly_chart(fig1, use_container_width=True)
        st.plotly_chart(fig3, use_container_width=True)
    
    with col2:
        st.plotly_chart(fig2, use_container_width=True)
        st.plotly_chart(fig4, use_container_width=True)
# Out:
# Overwriting app.py

# %%
! streamlit run app.py
# Out:
# ^C
